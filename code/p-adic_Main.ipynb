# %% [markdown]
# # Fleischer and Liu's computation
#
# available at theier [Github repository](https://github.com/liuyj8526/Computation-of-Elliptic-Units).

# %% [markdown]
# To initialize, specify:
#
# * $p$: prime for the p-adic calculations.
# * $N$: Defines the unit used for computation. In this code we implemented the units
#     - $N=4$        - [4]-3[2]+2[1]
#     - $N$ is prime - [N]-N[1]
# * $M$: $p$-adic precision. Ideally this value is at least 100.

# %%
p = 3
N = 2
M = 100

# %run Miscellaneous.ipynb
S = Qp(p, prec = 2*M+1, type = 'capped-rel', print_mode = 'series')	#Defines the padic ring of rationals, with specified precision.
R.<y> = PowerSeriesRing(S, sparse=True)	#Allows us to write polynomials in y with coefficients in S.

integral_1, integral_2, integral_3, integral_4 = getIntegrals(p,N,M)
# Out:
# Loading integrals from preexisting file.
# All integrals loaded.

# %% [markdown]
# Checks to see if a file exists with the necessary dictionaries of integrals given p, $N$, $M$.
# If so, loads the integrals from those files to save time.
# Otherwise, runs `algorithms 4_2a` and `4_2b` to calculate those integrals
# Note that especially depending on $M$, this may take several hours.
#
# **WARNING** : Do not terminate process when integrals are being loaded. Else the file storing the integrals will be erased.

# %% [markdown]
# Find discriminants $D$ such that $(D/p)=-1$, $(D/N)=1$, $D=1\pmod{4}$ when $N$ is prime and $=1\pmod{8}$ when $N=4$.

# %%
Ds = getGoodDs(N,p,500)

"""For each fundamental discriminant, calculate polynomial"""
for D in Ds:
    getPoly(D, N, integral_1, integral_2, integral_3, integral_4)
# Out:
# Output valid discriminants from 1 to 500, for p = 3 and N = 2:
# [44, 56, 92, 140, 152, 161, 188, 209, 236, 248, 284, 305, 308, 329, 332, 344, 377, 380, 428, 440, 473, 476, 497]
# Discriminant: 44
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -x^2 + 6*x*y + 2*y^2
# x^2 + 6*x*y - 2*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-6,-1): [379, 60, 120, 19]
# Output for BQF 2*x^2 - 6*x*y - y^2:
# log_p value: 3^2 + 2*3^3 + O(3^5)
# Order of p: 6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1358/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 44: X^2 + 1358/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 56
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -2*x^2 + 4*x*y + 5*y^2
# 2*x^2 + 4*x*y - 5*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,4,-5): [7, 20, 8, 23]
# Output for BQF 2*x^2 + 4*x*y - 5*y^2:
# log_p value: 3 + 2*3^4 + O(3^5)
# Order of p: -2
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 14/3^2
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 56: X^2 + 14/9*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 92
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -2*x^2 + 6*x*y + 7*y^2
# 2*x^2 + 6*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,6,-7): [431, 1680, 480, 1871]
# Output for BQF 2*x^2 + 6*x*y - 7*y^2:
# log_p value: 3 + O(3^5)
# Order of p: -6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 14/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 92: X^2 + 14/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 140
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -2*x^2 + 10*x*y + 5*y^2
# -x^2 + 10*x*y + 10*y^2
# x^2 + 10*x*y - 10*y^2
# 2*x^2 + 10*x*y - 5*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (10,-10,-1): [131, 12, 120, 11]
# GammaTau for BQF (2,10,-5): [11, 60, 24, 131]
# Output for BQF 10*x^2 - 10*x*y - y^2:
# log_p value: 2*3 + 2*3^4 + O(3^5)
# Order of p: 10
# Order of beta: 0
# Output for BQF 2*x^2 + 10*x*y - 5*y^2:
# log_p value: 3 + 2*3^2 + 2*3^4 + O(3^5)
# Order of p: 2
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -123556/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1570726/3^12
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: -123556/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 140: X^4 - 123556/59049*X^3 + 1570726/531441*X^2 - 123556/59049*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 152
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -x^2 + 12*x*y + 2*y^2
# x^2 + 12*x*y - 2*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-12,-1): [73, 6, 12, 1]
# Output for BQF 2*x^2 - 12*x*y - y^2:
# log_p value: 2*3^2 + 2*3^3 + 2*3^4 + O(3^5)
# Order of p: 6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -658/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 152: X^2 - 658/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 161
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -4*x^2 + 7*x*y + 7*y^2
# 4*x^2 + 7*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (4,-7,-7): [18271, 12992, 7424, 5279]
# Output for BQF 4*x^2 - 7*x*y - 7*y^2:
# log_p value: 3 + O(3^5)
# Order of p: -6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 14/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 161: X^2 + 14/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 188
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -2*x^2 + 10*x*y + 11*y^2
# 2*x^2 + 10*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,10,-11): [1247, 7392, 1344, 7967]
# Output for BQF 2*x^2 + 10*x*y - 11*y^2:
# log_p value: 3^3 + 3^4 + O(3^5)
# Order of p: -10
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 29294/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 188: X^2 + 29294/59049*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 209
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -4*x^2 + 7*x*y + 10*y^2
# 4*x^2 + 7*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (10,13,-1): [4691, 6440, 64400, 88411]
# Output for BQF 10*x^2 + 13*x*y - y^2:
# log_p value: 3^2 + 2*3^3 + O(3^5)
# Order of p: 6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1358/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 209: X^2 + 1358/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 236
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -5*x^2 + 6*x*y + 10*y^2
# 5*x^2 + 6*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (10,-6,-5): [781219, 365700, 731400, 342379]
# Output for BQF 10*x^2 - 6*x*y - 5*y^2:
# log_p value: 3^2 + 3^4 + O(3^5)
# Order of p: 18
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 657984878/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 236: X^2 + 657984878/387420489*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 248
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -2*x^2 + 12*x*y + 13*y^2
# 2*x^2 + 12*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,12,-13): [15, 104, 16, 111]
# Output for BQF 2*x^2 + 12*x*y - 13*y^2:
# log_p value: 3^2 + O(3^5)
# Order of p: -6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -658/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 248: X^2 - 658/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 284
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -5*x^2 + 8*x*y + 11*y^2
# 5*x^2 + 8*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-14,-11): [44342159, 31619280, 5748960, 4099439]
# Output for BQF 2*x^2 - 14*x*y - 11*y^2:
# log_p value: 2*3 + 3^3 + 3^4 + O(3^5)
# Order of p: -14
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -7162162/3^14
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 284: X^2 - 7162162/4782969*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 305
#
# Narrow Class Group of quadratic field K:[4]
#
# List of BQFs:
# -7*x^2 + 5*x*y + 10*y^2
# -4*x^2 + 15*x*y + 5*y^2
# 4*x^2 + 15*x*y - 5*y^2
# 7*x^2 + 5*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,5,-5): [349, 280, 784, 629]
# GammaTau for BQF (8,9,-7): [237, 392, 448, 741]
# Output for BQF 14*x^2 + 5*x*y - 5*y^2:
# log_p value: (2*d + 2)*3 + (d + 2)*3^2 + (d + 2)*3^3 + 2*d*3^4 + O(3^5)
# Order of p: 8
# Order of beta: 0
# Output for BQF 8*x^2 + 9*x*y - 7*y^2:
# log_p value: (d + 2)*3 + 3^2 + 3^3 + (2*d + 2)*3^4 + O(3^5)
# Order of p: -4
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 21637/2*3^8
# Rational reconstruction for sqrtD part of coefficient: 25/2*3^7
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 2335367/2*3^12
# Rational reconstruction for sqrtD part of coefficient: -7025/2*3^11
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 21637/2*3^8
# Rational reconstruction for sqrtD part of coefficient: 25/2*3^7
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 305: X^4 + (25/4374*sqrtD + 21637/13122)*X^3 + (-7025/354294*sqrtD + 2335367/1062882)*X^2 + (25/4374*sqrtD + 21637/13122)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 308
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -4*x^2 + 10*x*y + 13*y^2
# 4*x^2 + 10*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (4,10,-13): [151, 520, 160, 551]
# Output for BQF 4*x^2 + 10*x*y - 13*y^2:
# log_p value: 2*3^2 + 2*3^4 + O(3^5)
# Order of p: -6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1358/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 308: X^2 + 1358/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 329
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -8*x^2 + 3*x*y + 10*y^2
# 8*x^2 + 3*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (10,17,-1): [149143, 262032, 2620320, 4603687]
# Output for BQF 10*x^2 + 17*x*y - y^2:
# log_p value: 2*3^3 + 3^4 + O(3^5)
# Order of p: 10
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 29294/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 329: X^2 + 29294/59049*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 332
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -x^2 + 18*x*y + 2*y^2
# x^2 + 18*x*y - 2*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-18,-1): [26731, 1476, 2952, 163]
# Output for BQF 2*x^2 - 18*x*y - y^2:
# log_p value: 2*3^2 + O(3^5)
# Order of p: 18
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -748812178/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 332: X^2 - 748812178/387420489*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 344
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -7*x^2 + 6*x*y + 11*y^2
# 7*x^2 + 6*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-16,-11): [19381, 12342, 2244, 1429]
# Output for BQF 2*x^2 - 16*x*y - 11*y^2:
# log_p value: 2*3^2 + 2*3^3 + 2*3^4 + O(3^5)
# Order of p: 6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -658/3^6
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 344: X^2 - 658/729*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 377
#
# Narrow Class Group of quadratic field K:[4]
#
# List of BQFs:
# -8*x^2 + 5*x*y + 11*y^2
# -4*x^2 + 13*x*y + 13*y^2
# 4*x^2 + 13*x*y - 13*y^2
# 8*x^2 + 5*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (4,13,-13): [77, 312, 96, 389]
# GammaTau for BQF (8,5,-11): [173, 264, 192, 293]
# Output for BQF 4*x^2 + 13*x*y - 13*y^2:
# log_p value: (d + 2)*3 + (2*d + 1)*3^2 + 3^3 + 3^4 + O(3^5)
# Order of p: 8
# Order of beta: 0
# Output for BQF 8*x^2 + 5*x*y - 11*y^2:
# log_p value: (2*d + 2)*3 + d*3^2 + (d + 2)*3^3 + O(3^5)
# Order of p: -4
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1477/2*3^8
# Rational reconstruction for sqrtD part of coefficient: -595/2*3^7
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 3663335/2*3^12
# Rational reconstruction for sqrtD part of coefficient: -4165/2*3^11
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 1477/2*3^8
# Rational reconstruction for sqrtD part of coefficient: -595/2*3^7
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 377: X^4 + (-595/4374*sqrtD + 1477/13122)*X^3 + (-4165/354294*sqrtD + 3663335/1062882)*X^2 + (-595/4374*sqrtD + 1477/13122)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 380
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -7*x^2 + 10*x*y + 10*y^2
# -5*x^2 + 10*x*y + 14*y^2
# 5*x^2 + 10*x*y - 14*y^2
# 7*x^2 + 10*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,-10,-5): [59, 20, 56, 19]
# GammaTau for BQF (10,-10,-7): [59, 28, 40, 19]
# Output for BQF 14*x^2 - 10*x*y - 5*y^2:
# log_p value: 3 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 10
# Order of beta: 0
# Output for BQF 10*x^2 - 10*x*y - 7*y^2:
# log_p value: 2*3 + 3^2 + 3^3 + 2*3^4 + O(3^5)
# Order of p: 2
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -67876/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 798886/3^12
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: -67876/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 380: X^4 - 67876/59049*X^3 + 798886/531441*X^2 - 67876/59049*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 428
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -7*x^2 + 8*x*y + 13*y^2
# 7*x^2 + 8*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,-18,-13): [3461275, 2326116, 357864, 240499]
# Output for BQF 2*x^2 - 18*x*y - 13*y^2:
# log_p value: 3^4 + O(3^5)
# Order of p: 18
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -311916178/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 428: X^2 - 311916178/387420489*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 440
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -2*x^2 + 20*x*y + 5*y^2
# -x^2 + 20*x*y + 10*y^2
# x^2 + 20*x*y - 10*y^2
# 2*x^2 + 20*x*y - 5*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (10,-20,-1): [41, 2, 20, 1]
# GammaTau for BQF (2,20,-5): [1, 10, 4, 41]
# Output for BQF 10*x^2 - 20*x*y - y^2:
# log_p value: 3 + 2*3^3 + 2*3^4 + O(3^5)
# Order of p: 10
# Order of beta: 0
# Output for BQF 2*x^2 + 20*x*y - 5*y^2:
# log_p value: 2*3 + 3^2 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 2
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 46172/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 874918/3^12
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 46172/3^10
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 440: X^4 + 46172/59049*X^3 + 874918/531441*X^2 + 46172/59049*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 473
#
# Narrow Class Group of quadratic field K:[6]
#
# List of BQFs:
# -14*x^2 + 9*x*y + 7*y^2
# -8*x^2 + 11*x*y + 11*y^2
# -7*x^2 + 9*x*y + 14*y^2
# 7*x^2 + 9*x*y - 14*y^2
# 8*x^2 + 11*x*y - 11*y^2
# 14*x^2 + 9*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (16,5,-7): [67, 56, 128, 107]
# GammaTau for BQF (8,-11,-11): [131, 88, 64, 43]
# GammaTau for BQF (14,9,-7): [51, 56, 112, 123]
# Output for BQF 16*x^2 + 5*x*y - 7*y^2:
# log_p value: (d + 2)*3 + (d + 2)*3^3 + (2*d + 1)*3^4 + O(3^5)
# Order of p: -2
# Order of beta: 0
# Output for BQF 8*x^2 - 11*x*y - 11*y^2:
# log_p value: (2*d + 2)*3 + (d + 1)*3^2 + 2*3^3 + (d + 2)*3^4 + O(3^5)
# Order of p: 10
# Order of beta: 0
# Output for BQF 14*x^2 + 9*x*y - 7*y^2:
# log_p value: d*3 + d*3^2 + (2*d + 1)*3^3 + d*3^4 + O(3^5)
# Order of p: 6
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -86219/2*3^10
# Rational reconstruction for sqrtD part of coefficient: 1105/2*3^9
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: -27432523/2*3^16
# Rational reconstruction for sqrtD part of coefficient: 7735/2*3^11
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 978569179/2*3^18
# Rational reconstruction for sqrtD part of coefficient: -13610285/2*3^17
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: -27432523/2*3^16
# Rational reconstruction for sqrtD part of coefficient: 7735/2*3^11
#
# Coefficients of x^5:
# Rational reconstruction for rational part of coefficient: -86219/2*3^10
# Rational reconstruction for sqrtD part of coefficient: 1105/2*3^9
#
# Coefficients of x^6:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 473: X^6 + (1105/39366*sqrtD - 86219/118098)*X^5 + (7735/354294*sqrtD - 27432523/86093442)*X^4 + (-13610285/258280326*sqrtD + 978569179/774840978)*X^3 + (7735/354294*sqrtD - 27432523/86093442)*X^2 + (1105/39366*sqrtD - 86219/118098)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 476
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -10*x^2 + 6*x*y + 11*y^2
# -2*x^2 + 18*x*y + 19*y^2
# 2*x^2 + 18*x*y - 19*y^2
# 10*x^2 + 6*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (2,18,-19): [5039, 50160, 5280, 52559]
# GammaTau for BQF (10,6,-11): [20879, 29040, 26400, 36719]
# Output for BQF 2*x^2 + 18*x*y - 19*y^2:
# log_p value: 2*3^3 + 3^4 + O(3^5)
# Order of p: -18
# Order of beta: 0
# Output for BQF 10*x^2 + 6*x*y - 11*y^2:
# log_p value: 2*3 + 3^2 + O(3^5)
# Order of p: -2
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -309886372/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: -258036122/3^20
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: -309886372/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 476: X^4 - 309886372/387420489*X^3 - 258036122/3486784401*X^2 - 309886372/387420489*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 497
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -8*x^2 + 7*x*y + 14*y^2
# 8*x^2 + 7*x*y - 14*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,21,-1): [69735, 107824, 1509536, 2334039]
# Output for BQF 14*x^2 + 21*x*y - y^2:
# log_p value: 3 + 2*3^2 + 3^3 + 3^4 + O(3^5)
# Order of p: 14
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -7162162/3^14
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 497: X^2 - 7162162/4782969*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True

# %% [markdown]
# #####
